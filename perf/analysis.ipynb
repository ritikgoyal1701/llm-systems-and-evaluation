# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.9 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/5.5 MB 4.1 MB/s eta 0:00:01
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2.1 MB/5.5 MB, attempt 1)
# Resuming download numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (2.1 MB/5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.5 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...

# %%
import pandas as pd

df = pd.read_csv("metrics.csv")

print("P50 latency:", df["latency"].quantile(0.5))
print("P95 latency:", df["latency"].quantile(0.95))
print("P99 latency:", df["latency"].quantile(0.99))

print("Avg TTFT:", df["ttft"].mean())
print("Avg TPOT:", df["tpot"].mean())
# Out:
# P50 latency: 205.0433919429779
# P95 latency: 205.04464550018312
# P99 latency: 205.04475692749025
# Avg TTFT: 205.0433919429779
# Avg TPOT: 0.0926633129740683
